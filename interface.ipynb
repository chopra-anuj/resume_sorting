# %%
def find_closest_job(list_of_cv, job_desc):
    """  
    function:
    The function compares the job description with all the cv in the list and returns them in ascending order of their distance.
    First cv in the return value is the most matching cv, last cv least matching
    
    arguments:
    list_of_cv: this is a list of strings. 
    job_desc: A string for job description.
    
    returns:
    list of cv in ascending order of distance
    
    """
    
    return list_of_sorted_cv


def find_closest_cv(list_of_job_desc, cv):
    """ 
    function:
    The function compares the cv with all the job descriptions in the list and returns them in 
    ascending order of their distance.
    First cv in the return value is the most matching job description, last job description least matching
    
    arguments:
    list_of_job_desc: this is a list of strings corresponding to job descriptions. 
    cv: A string for cv.
    
    returns:
    list of job descriptions in ascending order of distance
    
    """
    
    return list_of_sorted_job_desc

# %%
def add_cv_to_map(key, cv_string):
    """
    function:
    It creates a representation or embedding for the string (or cv) and adds this representation to a dataframe for future usage.
    It saves time in case number of cv is very large. One can save the representations of all the cv and need not calcualte
    it everytime for comparison.
    
    arguments:
    key: a unique identifier for this cv. It expects a string value
    cv_string: contents of cv as string
    
    """

def delete_cv_from_map(key):
    """
    function:
    deletes the representation of cv in case it is no longer required
    
    arguments:
    key: the unique identifier for this cv
    
    """
    
def get_best_cv_from_map(job_desc, n = 1):
    """  
    function:
    The function compares the job description with all the cv in our map and returns top n ascending order of their distance.
    First cv in the return value is the most matching cv, last cv least matching
    
    arguments:
    job_desc: A string for job description.
    n = number of matching cv to return. Default = 1. Should be more than total number of cv in map.
    
    returns:
    list of cv in ascending order of distance
    
    """

# %%
def add_jd_to_map(key, job_description):
    """
    function:
    It creates a representation or embedding for the string (or job_description) and adds this representation 
    to a dataframe for future usage.
    It saves time in case number of job_description is very large. 
    One can save the representations of all the job_descriptions and need not calcualte
    it everytime for comparison.
    
    arguments:
    key: a unique identifier for this job_description. It expects a string value
    job_description: contents of job_description as string
    
    """

def delete_jd_from_map(key):
    """
    function:
    deletes the representation of job_description in case it is no longer required
    
    arguments:
    key: the unique identifier for this job_description
    
    """
    
def get_best_jd_from_map(cv_string, n = 1):
    """  
    function:
    The function compares the cv with all the job_descriptions in our map and returns top n in ascending order of their distance.
    First job_description in the return value is the most matching job_description, last job_description least matching
    
    arguments:
    cv_string: A string for cv.
    n = number of matching job_descriptions to return. Default = 1. Should be more than total number of job_descriptions in map.
    
    returns:
    list of job_descriptions in ascending order of distance
    
    """
